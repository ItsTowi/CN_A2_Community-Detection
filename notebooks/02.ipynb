# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

import os
os.getcwd()

# os.chdir("/home/jovyan/work/CN_A1_StructuralDescriptors")
os.chdir("/home/jovyan/work")
print(os.getcwd())
print(os.listdir())
# Out:
# /home/jovyan/work
# ['.git', 'A1-Log-Log-Histograms.pdf', 'activityA1', 'CN_A1_AntonioIglesias_PhilippeLemoine.pdf', 'GroupA1Z_Lemoine_Iglesias_A1.zip', 'notebooks']
